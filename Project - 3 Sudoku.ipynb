# %%
# Print out board 
board =    [['|','A1','A2','06','|','|','B1','07','B3','|','|','03','C2','04','|'],
            ['|','A4','03','09','|','|','02','B5','05','|','|','08','C5','01','|'],
            ['|','A7','A8','08','|','|','B7','01','04','|','|','C7','C8','C9','|'],
            ['--------------------------------------'],
            ['|','02','09','07','|','|','E1','08','06','|','|','F1','F2','F3','|'],
            ['|','D4','D5','01','|','|','E4','E5','E6','|','|','09','F5','F6','|'],
            ['|','D7','D8','D9','|','|','07','09','E9','|','|','01','06','08','|'],
            ['--------------------------------------'],
            ['|','G1','G2','G3','|','|','05','03','H3','|','|','06','I2','I3','|'],
            ['|','06','G5','03','|','|','08','H5','07','|','|','05','04','I6','|'],
            ['|','05','G8','02','|','|','H7','04','H9','|','|','07','I8','I9','|']]

def boards(board):
    
    for i in board:
        for j in i:
            print(j, end = " ")
        print()
boards(board)
# Out:
# | _ _ 6 | | _ 7 _ | | 3 _ 4 |
# | _ 3 9 | | 2 _ 5 | | 8 _ 1 |
# | _ _ 8 | | _ 1 4 | | _ _ _ |
# --------------------------------------
# | 2 9 7 | | _ 8 6 | | _ _ _ |
# | _ _ 1 | | _ _ _ | | 9 _ _ |
# | _ _ _ | | 7 9 _ | | 1 6 8 |
# --------------------------------------
# | _ _ _ | | 5 3 _ | | 6 _ _ |
# | 6 _ 3 | | 8 _ 7 | | 5 4 _ |
# | 5 _ 2 | | _ 4 _ | | 7 _ _ |

# %%
# Print out board 
game_board =    [['|','_','_','6','|','|','_','7','_','|','|','3','_','4','|'],
                ['|','_','3','9','|','|','2','_','5','|','|','8','_','1','|'],
                ['|','_','_','8','|','|','_','1','4','|','|','_','_','_','|'],
                ['-----------------------------'],
                ['|','2','9','7','|','|','_','8','6','|','|','_','_','_','|'],
                ['|','_','_','1','|','|','_','_','_','|','|','9','_','_','|'],
                ['|','_','_','_','|','|','7','9','_','|','|','1','6','8','|'],
                ['-----------------------------'],
                ['|','_','_','_','|','|','5','3','_','|','|','6','_','_','|'],
                ['|','6','_','3','|','|','8','_','7','|','|','5','4','_','|'],
                ['|','5','_','2','|','|','_','4','_','|','|','7','_','_','|']]

def boards(board):
    
    for i in board:
        for j in i:
            print(j, end = " ")
        print()
boards(game_board)
# Out:
# | _ _ 6 | | _ 7 _ | | 3 _ 4 |
# | _ 3 9 | | 2 _ 5 | | 8 _ 1 |
# | _ _ 8 | | _ 1 4 | | _ _ _ |
# -----------------------------
# | 2 9 7 | | _ 8 6 | | _ _ _ |
# | _ _ 1 | | _ _ _ | | 9 _ _ |
# | _ _ _ | | 7 9 _ | | 1 6 8 |
# -----------------------------
# | _ _ _ | | 5 3 _ | | 6 _ _ |
# | 6 _ 3 | | 8 _ 7 | | 5 4 _ |
# | 5 _ 2 | | _ 4 _ | | 7 _ _ |

# %%
position_board =[['|','A1','A2','A3','|','|','B1','B2','B3','|','|','C1','C2','C3','|'],
                ['|','A4','A5','A6','|','|','B4','B5','B6','|','|','C4','C5','C6','|'],
                ['|','A7','A8','A9','|','|','B7','B8','B9','|','|','C7','C8','C9','|'],
                ['--------------------------------------'],
                ['|','D1','D2','D3','|','|','E1','E2','E3','|','|','F1','F2','F3','|'],
                ['|','D4','D5','D6','|','|','E4','E5','E6','|','|','F4','F5','F6','|'],
                ['|','D7','D8','D9','|','|','E7','E8','E9','|','|','F7','F8','F9','|'],
                ['--------------------------------------'],
                ['|','G1','G2','G3','|','|','H1','H2','H3','|','|','I1','I2','I3','|'],
                ['|','G4','G5','G6','|','|','H4','H5','H6','|','|','I4','I5','I6','|'],
                ['|','G7','G8','G9','|','|','H7','H8','H9','|','|','I7','I8','I9','|']]

boards(position_board)
# Out:
# | A1 A2 A3 | | B1 B2 B3 | | C1 C2 C3 |
# | A4 A5 A6 | | B4 B5 B6 | | C4 C5 C6 |
# | A7 A8 A9 | | B7 B8 B9 | | C7 C8 C9 |
# --------------------------------------
# | D1 D2 D3 | | E1 E2 E3 | | F1 F2 F3 |
# | D4 D5 D6 | | E4 E5 E6 | | F4 F5 F6 |
# | D7 D8 D9 | | E7 E8 E9 | | F7 F8 F9 |
# --------------------------------------
# | G1 G2 G3 | | H1 H2 H3 | | I1 I2 I3 |
# | G4 G5 G6 | | H4 H5 H6 | | I4 I5 I6 |
# | G7 G8 G9 | | H7 H8 H9 | | I7 I8 I9 |

# %%
# Function to take an input
from IPython.display import clear_output
def user_choice1():
    choice1 = False
    positions = ['A1','A2','A3','A4','A5','A6','A7','A8','A9','B1','B2','B3','B4','B5','B6','B7','B8','B9','C1','C2','C3','C4','C5','C6','C7','C8','C9','D1','D2','D3','D4','D5','D6','D7','D8','D9','E1','E2','E3','E4','E5','E6','E7','E8','E9','F1','F2','F3','F4','F5','F6','F7','F8','F9','G1','G2','G3','G4','G5','G6','G7','G8','G9','H1','H2','H3','H4','H5','H6','H7','H8','H9','I1','I2','I3','I4','I5','I6','I7','I8','I9']
    p1_choice = '0'
    board = [['|A1','A2',' 6|','|B1',' 7','B3|','| 3','C2',' 4|'],['|A4',' 3',' 9|','| 2','B5',' 5|','| 8','C5',' 1|'],['|A7','A8',' 8|','|B7',' 1',' 4|','|C7','C8','C9|'],['--------------------------------'], ['| 2',' 9',' 7|','|E1',' 8',' 6|','|F1','F2','F3|'],['|D1','D2',' 1|','|E1','E2','E3|','| 9','F2','F3|'],['|D1','D2','D3|','| 7',' 9','E3|','| 1',' 6',' 8|'],['--------------------------------'],['|G1','G2','G3|','| 5',' 3','H3|','| 6','J2','J3|'],['| 6','G2',' 3|','| 8','H2',' 7|','| 5',' 4','J3|'],['| 5','G2',' 2|','|H1',' 4','H3|','| 7','J2','J3|']]

    while choice1 == False:
        print('Alpha-numeric key')
        boards(position_board)
        boards(game_board)
        p1_choice = input('Please select the alpha-numeric key to enter a digit in the corresponding position')
        clear_output()
        if p1_choice in positions:
            choice1 = True
            return p1_choice
        else:
             print('Please enter a valid selection (A-I)/(1-9)')
        
    
user_choice1()
# Out:
# 'A1'

# %%
p1_choice = user_choice1()
def replace1(p1_choice,board):
    
    abc = False 
    number_dict = {'A1':1,'A2':2,'A3':6,'A4':4,'A5':3,'A6':9,'A7':7,'A8':5,'A9':8,'B1':9,'B2':7,'B3':8,'B4':2,'B5':6,'B6':5,'B7':3,'B8':1,'B9':4,'C1':3,'C2':5,'C3':4,'C4':8,'C5':7,'C6':1,'C7':2,'C8':9,'C9':6,'D1':2,'D2':9,'D3':7,'D4':8,'D5':6,'D6':1,'D7':3,'D8':4,'D9':5,'E1':1,'E2':8,'E3':6,'E4':4,'E5':5,'E6':3,'E7':7,'E8':9,'E9':2,'F1':4,'F2':3,'F3':5,'F4':9,'F5':2,'F6':7,'F7':1,'F8':6,'F9':8,'G1':9,'G2':7,'G3':4,'G4':6,'G5':1,'G6':3,'G7':5,'G8':8,'G9':2,'H1':5,'H2':3,'H3':1,'H4':8,'H5':2,'H6':7,'H7':6,'H8':4,'H9':9,'I1':6,'I2':8,'I3':2,'I4':5,'I5':4,'I6':9,'I7':7,'I8':1,'I9':3}
    first_index = {'A1':0,'A2':0,'A3':0,'A4':1,'A5':1,'A6':1,'A7':2,'A8':2,'A9':2,'B1':0,'B2':0,'B3':0,'B4':1,'B5':1,'B6':1,'B7':2,'B8':2,'B9':2,'C1':0,'C2':0,'C3':0,'C4':1,'C5':1,'C6':1,'C7':2,'C8':2,'C9':2,'D1':4,'D2':4,'D3':4,'D4':5,'D5':5,'D6':5,'D7':6,'D8':6,'D9':6,'E1':4,'E2':4,'E3':4,'E4':5,'E5':5,'E6':5,'E7':6,'E8':6,'E9':6,'F1':4,'F2':4,'F3':4,'F4':5,'F5':5,'F6':5,'F7':6,'F8':6,'F9':6,'G1':8,'G2':8,'G3':8,'G4':9,'G5':9,'G6':9,'G7':10,'G8':10,'G9':10,'H1':8,'H2':8,'H3':8,'H4':9,'H5':9,'H6':9,'H7':10,'H8':10,'H9':10,'I1':8,'I2':8,'I3':8,'I4':9,'I5':9,'I6':9,'I7':10,'I8':10,'I9':10}
    second_index = {'A1':1,'A2':2,'A3':3,'A4':1,'A5':2,'A6':3,'A7':1,'A8':2,'A9':3,'B1':6,'B2':7,'B3':8,'B4':6,'B5':7,'B6':8,'B7':6,'B8':7,'B9':8,'C1':11,'C2':12,'C3':13,'C4':11,'C5':12,'C6':13,'C7':11,'C8':12,'C9':13,'D1':1,'D2':2,'D3':3,'D4':1,'D5':2,'D6':3,'D7':1,'D8':2,'D9':3,'E1':6,'E2':7,'E3':8,'E4':6,'E5':7,'E6':8,'E7':6,'E8':7,'E9':8,'F1':11,'F2':12,'F3':13,'F4':11,'F5':12,'F6':13,'F7':11,'F8':12,'F9':13,'G1':1,'G2':2,'G3':3,'G4':1,'G5':2,'G6':3,'G7':1,'G8':2,'G9':3,'H1':6,'H2':7,'H3':8,'H4':6,'H5':7,'H6':8,'H7':6,'H8':7,'H9':8,'I1':11,'I2':12,'I3':13,'I4':11,'I5':12,'I6':13,'I7':11,'I8':12,'I9':13}
    tally = 3
  

    boards(position_board)
    boards(game_board)
    while abc == False:
        p1_choice = user_choice1()
        number = input('Please select correct digit for position from 1 to 9 ')
        
        if number.isdigit() == False:
            print('Please enter a digit')
        elif int(number) == 10:
            abc = True
        elif int(number) < 1 or int(number) > 9:
            print('Please select a valid entry between 01 to 09')
        elif number_dict[p1_choice] == int(number):
            game_board[first_index[p1_choice]][second_index[p1_choice]] = number
            boards(game_board)
        
   
        else:
             tally = tally - 1
             print('That is incorrect, you have {} more incorrect choices'.format(tally))
             if tally < 1:
                          return('Sorry you have made too many incorrect choices, Game Over!')
                    
        
        
    
  
    return boards(game_board)

# %%
replace1(p1_choice,board)
# Out:
# Please select correct digit for position from 1 to 9 10
# | 1 2 6 | | _ 7 _ | | 3 _ 4 |
# | _ 3 9 | | 2 6 5 | | 8 _ 1 |
# | _ _ 8 | | _ 1 4 | | _ 9 6 |
# -----------------------------
# | 2 9 7 | | 1 8 6 | | 4 3 _ |
# | 8 _ 1 | | _ 5 _ | | 9 _ _ |
# | _ 4 _ | | 7 9 2 | | 1 6 8 |
# -----------------------------
# | 9 7 _ | | 5 3 _ | | 6 8 2 |
# | 6 _ 3 | | 8 2 7 | | 5 4 _ |
# | 5 _ 2 | | _ 4 _ | | 7 _ _ |
